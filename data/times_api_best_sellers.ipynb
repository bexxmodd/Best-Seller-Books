# %%
import numpy as np
import pandas as pd
import requests
import json
import datetime
import time

from pandas.io.json import json_normalize
from TimesExtractor import TimesExtractor

# %% [markdown]
# Connecting to the Times Best Sellers API to get the list of books

# %%
year1 = TimesExtractor('2011-05-01', '2012-05-01', 'W')
dic1 = year1.extractor()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 57/57 [00:18<00:00,  3.16it/s]

# %%
year2 = TimesExtractor('2011-05-01', '2011-06-01', 'W')
dic2 = year1.extractor()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 53/53 [00:17<00:00,  3.06it/s]

# %%
dic1
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company.  All Rights Reserved.',
#  'num_results': 15,
#  'last_modified': '2020-05-20T23:39:01-04:00',
#  'results': {'list_name': 'Combined Print and E-Book Fiction',
#   'list_name_encoded': 'combined-print-and-e-book-fiction',
#   'bestsellers_date': '2020-05-16',
#   'published_date': '2020-05-31',
#   'published_date_description': 'latest',
#   'next_published_date': '',
#   'previous_published_date': '2020-05-24',
#   'display_name': 'Combined Print & E-Book Fiction',
#   'normal_list_ends_at': 15,
#   'updated': 'WEEKLY',
#   'books': [{'rank': 1,
#     'rank_last_week': 2,
#     'weeks_on_list': 3,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0385545932',
#     'primary_isbn13': '9780385545938',
#     'publisher': 'Doubleday',
#     'description': 'The line between fact and fiction becomes blurred when an author of thrillers is found dead after a hurricane hits Camino Island.',
# ...

# %%
dic2 = dic2['results']['books']

# %%
keys = ['weeks_on_list', 'primary_isbn10', 'primary_isbn13',
       'publisher', 'description', 'title', 'author']

# %%
def converter(dic, keys):
    converted = {}
    for n in range(0, len(dic)):
        for k in keys:
            converted.setdefault(k, []).append(dic[n][k])
    return converted

# %%
bbb_di = converter(dic1, keys)

# %%
def conv(dic, keys):
    converted = [[converted.setdefault(k, []).append(dic[n][k]) for k in keys] for n in range(0, len(dic))]
    return converted

# %%
bbb_du = conv(dic1, keys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-210-a26c9117cccc> in <module>
# ----> 1 bbb_du = conv(dic1, keys)
#
# <ipython-input-209-00664b5cd4af> in conv(dic, keys)
#       1 def conv(dic, keys):
# ----> 2     converted = {[converted.setdefault(k, []).append(dic[n][k]) for k in keys] for n in range(0, len(dic))}
#       3     return converted
#       4
#
# <ipython-input-209-00664b5cd4af> in <setcomp>(.0)
#       1 def conv(dic, keys):
# ----> 2     converted = {[converted.setdefault(k, []).append(dic[n][k]) for k in keys] for n in range(0, len(dic))}
#       3     return converted
#       4
#
# <ipython-input-209-00664b5cd4af> in <listcomp>(.0)
#       1 def conv(dic, keys):
# ----> 2     converted = {[converted.setdefault(k, []).append(dic[n][k]) for k in keys] for n in range(0, len(dic))}
#       3     return converted
#       4
#
# ...

# %%
df = pd.DataFrame.from_dict(bbb_du)
df.head(20)
# Out:
#        0     1     2     3     4     5     6
# 0   None  None  None  None  None  None  None
# 1   None  None  None  None  None  None  None
# 2   None  None  None  None  None  None  None
# 3   None  None  None  None  None  None  None
# 4   None  None  None  None  None  None  None
# 5   None  None  None  None  None  None  None
# 6   None  None  None  None  None  None  None
# 7   None  None  None  None  None  None  None
# 8   None  None  None  None  None  None  None
# 9   None  None  None  None  None  None  None
# 10  None  None  None  None  None  None  None
# 11  None  None  None  None  None  None  None
# 12  None  None  None  None  None  None  None
# 13  None  None  None  None  None  None  None
# 14  None  None  None  None  None  None  None

# %%
book_dic
# Out:
# {'rank': 3,
#  'weeks_on_list': 4,
#  'primary_isbn10': '0307272117',
#  'primary_isbn13': '9780307272119',
#  'publisher': 'Knopf Doubleday',
#  'description': 'A hacker and a journalist investigate the disappearance of a Swedish heiress 40 years earlier; the first volume in the Millennium trilogy.',
#  'title': 'THE GIRL WITH THE DRAGON TATTOO',
#  'author': 'Stieg Larsson',
#  'contributor': 'by Stieg Larsson'}

# %%
def dict_extractor(dic):
    df = {}
    for n in range(0, len(bookslist)):
        df[k] = df[n][k]
    return df

# %%
df = dict_extractor(bookslist)
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-35b8f5cb6185> in <module>
# ----> 1 df = dict_extractor(bookslist)
#       2 print(df)
#
# <ipython-input-36-2ca03d1871fb> in dict_extractor(dic)
#       2     df = {}
#       3     for k, n in zip(keys, range(0, len(bookslist))):
# ----> 4         df[k] = df[n][k]
#       5     return df
#
# KeyError: 0

# %%
df1 = pd.DataFrame(df, columns=keys)
df1.head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1653                 blocks = [
# -> 1654                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1655                 ]
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3046
# -> 3047     return klass(values, ndim=ndim, placement=placement)
#    3048
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#    2594
# -> 2595         super().__init__(values, ndim=ndim, placement=placement)
#    2596
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     124             raise ValueError(
# ...

# %%
start_date = datetime.date(2011, 5 , 1)
end_date = datetime.date(2020, 5, 1)

# %%
dates = pd.date_range(start='2011-5-1', end='2020-5-1', freq='W')
print(dates)
# Out:
# DatetimeIndex(['2011-05-01', '2011-05-08', '2011-05-15', '2011-05-22',
#                '2011-05-29', '2011-06-05', '2011-06-12', '2011-06-19',
#                '2011-06-26', '2011-07-03',
#                ...
#                '2020-02-23', '2020-03-01', '2020-03-08', '2020-03-15',
#                '2020-03-22', '2020-03-29', '2020-04-05', '2020-04-12',
#                '2020-04-19', '2020-04-26'],
#               dtype='datetime64[ns]', length=470, freq='W-SUN')

# %%
import time

# %%
for n in range(0, 5):
    time.sleep(5)
    print(n)
# Out:
# 0
# 1
# 2
# 3
# 4
